# %% [markdown]
# ![how-to-scrapr-data-from-twitter-python](https://user-images.githubusercontent.com/54896849/65834493-1c3cee00-e2f9-11e9-95ab-3d5e2114b6af.jpg)

# %% [markdown]
# # Importing Libraries

# %%
import tweepy
import csv
import json
import os
import glob
import pandas as pd

# %% [markdown]
# # Creating json file containing tokens

# %% [markdown]
#  - Once you get your Twitter dev account approved, use the 4 secret tokens inside the following code to save them in a json file.
#
#  - This way, you can just access the json file, instead of copy pasting the four secret tokens in every program, where you need to access the twitter API.```

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

import json

# create a dictionary to store your twitter credentials

twitter_cred = dict()

# Enter your own consumer_key, consumer_secret, access_key and access_secret
# Replacing the stars ("********")

twitter_cred['CONSUMER_KEY'] = "********"
twitter_cred['CONSUMER_SECRET'] = "********"
twitter_cred['ACCESS_KEY'] = "********"
twitter_cred['ACCESS_SECRET'] = "********"

# Save the information to a json so that it can be reused in code without exposing
# the secret info to public

with open('twitter_credentials.json', 'w') as secret_info:
    json.dump(twitter_cred, secret_info, indent=4, sort_keys=True)

# %% [markdown]
# # Tweepy installation
# - tweepy module will help us interact with the twitter api more easily

# %%
# !pip install tweepy

# %% [markdown]
# # Coming to the code

# %% [markdown]
# ### you can run this code to get the tweets of a person in csv format

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-



# load Twitter API credentials

with open('twitter_credentials.json') as cred_data:
    info = json.load(cred_data)
    consumer_key = info['CONSUMER_KEY']
    consumer_secret = info['CONSUMER_SECRET']
    access_key = info['ACCESS_KEY']
    access_secret = info['ACCESS_SECRET']

def get_all_tweets(screen_name):

# Twitter allows access to only 3240 tweets via this method

# Authorization and initialization

    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)

    # initialization of a list to hold all Tweets

    all_the_tweets = []

    # We will get the tweets with multiple requests of 200 tweets each

    new_tweets = api.user_timeline(screen_name=screen_name, count=200)

    # saving the most recent tweets

    all_the_tweets.extend(new_tweets)

    # save id of 1 less than the oldest tweet

    oldest_tweet = all_the_tweets[-1].id - 1

# grabbing tweets till none are left

    while len(new_tweets)> 0:
    # The max_id param will be used subsequently to prevent duplicates
        new_tweets = api.user_timeline(screen_name=screen_name,
        count=200, max_id=oldest_tweet)

        # save most recent tweets

        all_the_tweets.extend(new_tweets)

        # id is updated to oldest tweet - 1 to keep track

        oldest_tweet = all_the_tweets[-1].id - 1
        print ('...%s tweets have been downloaded so far' % len(all_the_tweets))

        # transforming the tweets into a 2D array that will be used to populate the csv

        outtweets = [[tweet.id_str, tweet.created_at,
        tweet.text.encode('utf-8')] for tweet in all_the_tweets]

    # writing to the csv file in the directory "C:/Users/Apar/Twitter Sentiment Analysis/csv_files/"

    with open("C:/Users/Apar/Twitter Sentiment Analysis/csv_files/"+screen_name + '_tweets.csv', 'w', encoding='utf8') as f:
        #writer = csv.writer("C:/Users/Apar/Twitter Sentiment Analysis/csv_files/"+f)
        writer = csv.writer(f)
        writer.writerow(['id', 'created_at', 'text'])
        writer.writerows(outtweets)

# Enter the twitter handle of the person concerned

# %%
# BarackObama
# Cristiano
# Rihanna
# Amazon
w=input('Do you want more tweets(y/n): ').lower()
while(w=='y'):
    p=input("Enter the twitter handle of the person whose tweets you want to download:- ")
    get_all_tweets(p)
    w=input('Do you want more tweets(y/n): ').lower()
# Out:
# Do you want more tweets(y/n): y

# %% [markdown]
# ### Combining multiple CSV files into a single CSV file

# %%
os.chdir("C:/Users/Apar/Twitter Sentiment Analysis/csv_files")
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# 4      b"@pegs4legs That's awesome, Erin! What kind o...
# 5      b'Here\xe2\x80\x99s how feedback from visually...
# 6      b"@EAKirkCuomo Aw! How cute! What's the puppy'...
# 7      b'RT @amazonnews: From making Alexa a \xe2\x80...
# 8      b'From Echo Frames, all-day glasses with Alexa...
# 9      b'@amyncranston \xf0\x9f\x92\x9b \xf0\x9f\x92\...
# 10     b"@dianakrueziu Thanks for the shout out! We'r...
# 11     b"@CJIhme Thanks for sharing your experience w...
# 12     b'Hundreds of kids from @StJude in Memphis too...
# 13     b'RT @StJude: Boxes and bots and bytes, oh my!...
# 14     b'RT @PrimeVideo: Honored to bring home 15 #Em...
# 15     b'RT @PrimeVideo: Pop open a canned gin and to...
# 16     b'RT @ReeseW: #PhoebeWallerBridge you are a RO...
# 17     b'@SUHOismy24 \xf0\x9f\x98\x84\xf0\x9f\x98\x84...
# 18     b'@BurlesqueOnIce Shhh...cat nap in progress. ...
# 19     b"@squidleeee Hey, Sydnee. We're glad to hear ...
# 20     b'@marie_alxandria \xf0\x9f\x91\x8d\xf0\x9f\x9...
# 21     b"@SandBanphrionsa Thank you for sharing your ...
# 22     b'RT @amazonnews: Today, Amazon and @GlobalOpt...
# 23     b'@knar89 This is a natural response to anythi...
# 24          b'@WhoMEA WOO! Early packages are the best!'
# 25     b"@x0charli You're welcome. We're happy to sup...
# 26     b"@RatesDaGoldfish We do love your paw-somely ...
# 27     b"@T3CHGY007 Yay! What's your favorite genre o...
# 28     b"@BlueBoxRedBox Hello, Andrew. We're glad to ...
# 29     b"@mari1967 What a purrrfectly sweet fur baby!...
# ...                                                  ...
# 19226  b'All I see is $ign$ tho #SlayItUp #navi \xe2\...
# 19227  b'All I got are these photographs #phuckyoshir...
# 19228     b'#SINGLEcover for #STAY http://t.co/Ta8Y8dHd'
# 19229  b'#SINGLEcover for #POURitUP http://t.co/Xz6jH...
# 19230  b'COMPLEX VIDEO #watch -----&gt; http://t.co/c...
# 19231  b'RT @_MAYOR_: Only those who will risk going ...
# 19232                        b'#dn http://t.co/D1Yv3ocx'
# 19233                   b'#complex http://t.co/Qr9IpFzV'
# 19234       b'#complex #selfieLife http://t.co/Rd2MJ6gx'
# 19235  b'#complex #RihannaforRiverIsland jacket #phuc...
# 19236                   b'#complex http://t.co/r0AoiXYT'
# 19237               b'POV #complex http://t.co/BNPHjWZv'
# 19238                   b'#complex http://t.co/uOK3cdzv'
# 19239                                    b'#phuckyofave'
# 19240                            b'#2013 here we go....'
# 19241  b'UNAPOLOGETIC #complex #cover7 http://t.co/Qh...
# 19242  b'Talk That Talk #complex #cover6 http://t.co/...
# 19243      b'LOUD #complex #cover5 http://t.co/K9aihExC'
# 19244   b'Rated R #complex #cover4 http://t.co/uSbc1Ccc'
# 19245  b'Good Girl Gone Bad #Complex #cover3 http://t...
# 19246  b'A Girl Like Me #Complex #cover2 http://t.co/...
# 19247  b'Music of the Sun #Complex #cover1 http://t.c...
# 19248  b'#COMPLEX #7covers I shot a cover for each er...
# 19249             b'#mySundaynight http://t.co/JKnk45D3'
# 19250           b'My Sunday night! http://t.co/ljxFegWs'
# 19251                                             b'420'
# 19252                        b'#dn http://t.co/dqwSxxEB'
# 19253                  b'#naviRdie http://t.co/Sh2DRbZg'
# 19254  b'Christmas all over again! Thank you Marc #ja...
# 19255  b'#red #croc #newphuckmepumpz #blahnikbitches ...
#
# [19256 rows x 3 columns]
